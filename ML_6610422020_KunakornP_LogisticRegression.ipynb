# %% [markdown]
# <a href="https://colab.research.google.com/github/KunakornMart/DADS6003/blob/main/ML_6610422020_KunakornP_LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Library

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Machine learning
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score,accuracy_score,f1_score

# %% [markdown]
# #a. เลือกหุ้น จาก Yahoo Finance โดยใช้ Timeframe 1 hour
# โดยผมเลือก Osprey Bitcoin Trust (OBTC) : https://finance.yahoo.com/quote/OBTC

# %% [markdown]
# ดึงข้อมูล Osprey Bitcoin Trust ([OBTC](https://finance.yahoo.com/quote/OBTC))

# %%
obtc = yf.Ticker('OBTC')
interval = '1h'
start = '2022-02-22'
end = '2024-01-14'
df = obtc.history(interval=interval,start=start,end=end)
df = df.dropna()
df
# Out:
#                               Open    High     Low   Close  Volume  Dividends  \
# Datetime
# 2022-02-22 09:30:00-05:00  10.5500  10.550  10.080  10.246       0        0.0
# 2022-02-22 10:30:00-05:00  10.2400  10.270  10.130  10.196   12275        0.0
# 2022-02-22 11:30:00-05:00  10.1300  10.174  10.000  10.010    5327        0.0
# 2022-02-22 12:30:00-05:00  10.0125  10.100  10.010  10.054    5846        0.0
# 2022-02-22 13:30:00-05:00  10.1500  10.150  10.070  10.070     421        0.0
# ...                            ...     ...     ...     ...     ...        ...
# 2024-01-12 11:30:00-05:00  12.8000  12.820  12.080  12.180    5189        0.0
# 2024-01-12 12:30:00-05:00  12.5000  12.640  12.090  12.090    3522        0.0
# 2024-01-12 13:30:00-05:00  12.5000  12.540  12.260  12.540    6775        0.0
# 2024-01-12 14:30:00-05:00  12.5000  12.540  12.500  12.510    1702        0.0
# 2024-01-12 15:30:00-05:00  12.6900  12.695  12.645  12.680    4018        0.0
#
#                            Stock Splits  Capital Gains
# Datetime
# 2022-02-22 09:30:00-05:00           0.0            0.0
# 2022-02-22 10:30:00-05:00           0.0            0.0
# 2022-02-22 11:30:00-05:00           0.0            0.0
# 2022-02-22 12:30:00-05:00           0.0            0.0
# 2022-02-22 13:30:00-05:00           0.0            0.0
# ...                                 ...            ...
# 2024-01-12 11:30:00-05:00           0.0            0.0
# 2024-01-12 12:30:00-05:00           0.0            0.0
# 2024-01-12 13:30:00-05:00           0.0            0.0
# 2024-01-12 14:30:00-05:00           0.0            0.0
# 2024-01-12 15:30:00-05:00           0.0            0.0
#
# [2761 rows x 8 columns]

# %% [markdown]
# # b. เพิ่ม Column ที่เราสนใจ
# โดยผมเลือก Grayscale Bitcoin Trust (GBTC) : https://finance.yahoo.com/quote/GBTC  เพื่อนำมาเปรียบเทียบและใช้สร้างโมเดลด้วย

# %% [markdown]
# ดึงข้อมูล Grayscale Bitcoin Trust ([GBTC](https://finance.yahoo.com/quote/GBTC))

# %%
gbtc = yf.Ticker('GBTC')
interval = '1h'
start = '2022-02-22'
end = '2024-01-14'
df2 = gbtc.history(interval=interval,start=start,end=end)
df2 = df2.dropna()
df2
# Out:
#                                 Open       High        Low      Close  \
# Datetime
# 2022-02-22 09:30:00-05:00  25.650000  26.475000  25.500000  26.230000
# 2022-02-22 10:30:00-05:00  26.230000  26.230000  25.700001  25.910000
# 2022-02-22 11:30:00-05:00  25.889999  26.000000  25.600000  25.870001
# 2022-02-22 12:30:00-05:00  25.860001  25.959999  25.690001  25.799999
# 2022-02-22 13:30:00-05:00  25.809999  26.100000  25.799999  26.035000
# ...                              ...        ...        ...        ...
# 2024-01-12 11:30:00-05:00  38.480000  38.560001  37.770000  38.070000
# 2024-01-12 12:30:00-05:00  38.070000  38.439999  37.980000  38.150101
# 2024-01-12 13:30:00-05:00  38.158501  38.349998  37.900002  38.299999
# 2024-01-12 14:30:00-05:00  38.299999  38.580002  38.130001  38.535000
# 2024-01-12 15:30:00-05:00  38.540001  38.770000  38.490002  38.580002
#
#                             Volume  Dividends  Stock Splits  Capital Gains
# Datetime
# 2022-02-22 09:30:00-05:00        0        0.0           0.0            0.0
# 2022-02-22 10:30:00-05:00  1035286        0.0           0.0            0.0
# 2022-02-22 11:30:00-05:00   962629        0.0           0.0            0.0
# 2022-02-22 12:30:00-05:00   967340        0.0           0.0            0.0
# 2022-02-22 13:30:00-05:00   861394        0.0           0.0            0.0
# ...                            ...        ...           ...            ...
# 2024-01-12 11:30:00-05:00  6816540        0.0           0.0            0.0
# 2024-01-12 12:30:00-05:00  4127433        0.0           0.0            0.0
# 2024-01-12 13:30:00-05:00  4199162        0.0           0.0            0.0
# 2024-01-12 14:30:00-05:00  5335225        0.0           0.0            0.0
# 2024-01-12 15:30:00-05:00  3693125        0.0           0.0            0.0
#
# [3321 rows x 8 columns]

# %%
#Plot กราฟหุ้น 2 ตัว โดยใช้ Matplotlib

import matplotlib.pyplot as plt
plt.figure(figsize=(16, 8))

df['Close'].plot(label='OBTC', color='orange')
df2['Close'].plot(label='GBTC')

plt.title('OBTC & GBTC')
plt.xlabel('Datetime')
plt.ylabel('Price (USD)')

plt.legend()

# %% [markdown]
# # ปรับแต่งข้อมูล

# %% [markdown]
# *เนื่องจากข้อมูลของ"GBTC" มีจำนวนแถวมากกว่า"OBTC" จึงใช้แถวของ"OBTC"เป็นหลัก โดยการวนลูปตาม Datetime ของ"OBTC" แล้วนำค่า"GBTC" ไปใส่ให้ตรงกัน โดยอ้างอิงจากข้อมูล Datetime เดียวกัน

# %%
#เปลี่ยน Format Datetime ก่อน
df = df.reset_index()
df2 = df2.reset_index()
df['Datetime'] = pd.to_datetime(df['Datetime'], format = '%Y-%m-%d %H:%M:%S%:z').dt.strftime('%Y-%m-%d %H:%M')
df2['Datetime'] = pd.to_datetime(df2['Datetime'], format = '%Y-%m-%d %H:%M:%S%:z').dt.strftime('%Y-%m-%d %H:%M')

# %%
#สร้างคอลัมน์เพิ่มก่อนวนลูป เพื่อให้วนลูปแล้วเอาข้อมูลมาใส่ที่ลอลัมน์นี้
df['GBTC_Open'] = None
df['GBTC_Close'] = None

#วนลูปเอาราคาเปิด-ปิด ของ GBTC มาใส่
for i,date in enumerate(df['Datetime']):
    df['GBTC_Open'][i] = df2['Open'][df2['Datetime']==df.loc[i,'Datetime']].to_string(index=False)
    df['GBTC_Close'][i] = df2['Close'][df2['Datetime']==df.loc[i,'Datetime']].to_string(index=False)

# %% [markdown]
# ข้อมูลใน dataframe รวม หลังจากเพิ่ม Column GBTC_Open, GBTC_Close

# %%
df
# Out:
#               Datetime     Open    High     Low   Close  Volume  Dividends  \
# 0     2022-02-22 09:30  10.5500  10.550  10.080  10.246       0        0.0
# 1     2022-02-22 10:30  10.2400  10.270  10.130  10.196   12275        0.0
# 2     2022-02-22 11:30  10.1300  10.174  10.000  10.010    5327        0.0
# 3     2022-02-22 12:30  10.0125  10.100  10.010  10.054    5846        0.0
# 4     2022-02-22 13:30  10.1500  10.150  10.070  10.070     421        0.0
# ...                ...      ...     ...     ...     ...     ...        ...
# 2756  2024-01-12 11:30  12.8000  12.820  12.080  12.180    5189        0.0
# 2757  2024-01-12 12:30  12.5000  12.640  12.090  12.090    3522        0.0
# 2758  2024-01-12 13:30  12.5000  12.540  12.260  12.540    6775        0.0
# 2759  2024-01-12 14:30  12.5000  12.540  12.500  12.510    1702        0.0
# 2760  2024-01-12 15:30  12.6900  12.695  12.645  12.680    4018        0.0
#
#       Stock Splits  Capital Gains  GBTC_Open GBTC_Close
# 0              0.0            0.0      25.65      26.23
# 1              0.0            0.0      26.23      25.91
# 2              0.0            0.0  25.889999  25.870001
# 3              0.0            0.0  25.860001  25.799999
# 4              0.0            0.0  25.809999     26.035
# ...            ...            ...        ...        ...
# 2756           0.0            0.0      38.48      38.07
# 2757           0.0            0.0      38.07  38.150101
# 2758           0.0            0.0  38.158501  38.299999
# 2759           0.0            0.0  38.299999     38.535
# 2760           0.0            0.0  38.540001  38.580002
#
# [2761 rows x 11 columns]

# %% [markdown]
# Type ของข้อมูลแต่ละ Column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2761 entries, 0 to 2760
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Datetime       2761 non-null   object
#  1   Open           2761 non-null   float64
#  2   High           2761 non-null   float64
#  3   Low            2761 non-null   float64
#  4   Close          2761 non-null   float64
#  5   Volume         2761 non-null   int64
#  6   Dividends      2761 non-null   float64
#  7   Stock Splits   2761 non-null   float64
#  8   Capital Gains  2761 non-null   float64
#  9   GBTC_Open      2761 non-null   object
#  10  GBTC_Close     2761 non-null   object
# dtypes: float64(7), int64(1), object(3)
# memory usage: 237.4+ KB

# %% [markdown]
# แปลง Column GBTC_Open, GBTC_Close เป็น float64 เหมือนข้อมูลอื่นๆ

# %%
df['GBTC_Open'] = pd.to_numeric(df['GBTC_Open'],errors='coerce')
df['GBTC_Close'] = pd.to_numeric(df['GBTC_Close'],errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2761 entries, 0 to 2760
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Datetime       2761 non-null   object
#  1   Open           2761 non-null   float64
#  2   High           2761 non-null   float64
#  3   Low            2761 non-null   float64
#  4   Close          2761 non-null   float64
#  5   Volume         2761 non-null   int64
#  6   Dividends      2761 non-null   float64
#  7   Stock Splits   2761 non-null   float64
#  8   Capital Gains  2761 non-null   float64
#  9   GBTC_Open      2759 non-null   float64
#  10  GBTC_Close     2759 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 237.4+ KB

# %% [markdown]
# # Visualization

# %% [markdown]
# กราฟ Time Series ของ Osprey Bitcoin Trust ([OBTC](https://finance.yahoo.com/quote/OBTC))

# %%
fig = px.line(df, x="Datetime", y="Close")
fig.update_layout(title_text='Osprey Bitcoin Trust (OBTC)', title_x=0.5 ,yaxis_title="Price (USD)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="24fa5a2e-e11f-47a0-b353-22aced686472" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24fa5a2e-e11f-47a0-b353-22aced686472")) {                    Plotly.newPlot(                        "24fa5a2e-e11f-47a0-b353-22aced686472",                        [{"hovertemplate":"Datetime=%{x}\u003cbr\u003eClose=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2022
","2022-03-10 13:30","2022-03-10 14:30","2022-03-11 09:30","2022-03-11 11:30","2022-03-11 13:30","2022-03-11 14:30","2022-03-11 15:30","2022-03-14 09:30","2022-03-14 10:30","2022-03-14 11:30","2022-03-14 14:30","2022-03-14 15:30","2022-03-15 09:30","2022-03-15 10:30","2022-03-15 11:30","2022-03-15 12:30","2022-03-15 13:30","2022-03-15 14:30","2022-03-15 15:30","2022-03-16 09:30","2022-03-16 10:30","2022-03-16 12:30","2022-03-16 13:30","2022-03-16 14:30","2022-03-16 15:30","2022-03-17 09:30","2022-03-17 10:30","2022-03-17 11:30","2022-03-17 12:30","2022-03-17 13:30","2022-03-17 14:30","2022-03-17 15:30","2022-03-18 09:30","2022-03-18 10:30","2022-03-18 11:30","2022-03-18 12:30","2022-03-18 13:30","2022-03-18 14:30","2022-03-18 15:30","2022-03-21 09:30","2022-03-21 10:30","2022-03-21 12:30","2022-03-21 13:30","2022-03-21 14:30","2022-03-21 15:30","2022-03-22 09:30","2022-03-22 10:30","2022-03-22 11:30","2022-03-22 13:30","2022-03-22 14:30","2022-03-22 15:30","2022-03-23 09:30","2022-03-23 10:30","2022-03-23 11:30","2022-03-23 12:30","2022-03-23 13:30","2022-03-23 14:30","2022-03-23 15:30","2022-03-24 09:30","2022-03-24 10:30","2022-03-24 11:30","2022-03-24 12:30","2022-03-24 13:30","2022-03-24 14:30","2022-03-24 15:30","2022-03-25 09:30","2022-03-25 10:30","2022-03-25 11:30","2022-03-25 12:30","2022-03-25 13:30","2022-03-25 14:30","2022-03-25 15:30","2022-03-28 09:30","2022-03-28 10:30","2022-03-28 11:30","2022-03-28 12:30","2022-03-28 13:30","2022-03-28 14:30","2022-03-28 15:30","2022-03-29 09:30","2022-03-29 10:30","2022-03-29 11:30","2022-03-29 12:30","2022-03-29 13:30","2022-03-29 14:30","2022-03-29 15:30","2022 ...

# %% [markdown]
# เปรียบเทียบกับกราฟ ข้อ a.OBTC และข้อ b.GBTC

# %%
fig_all = go.Figure()
fig_all.add_trace(go.Scatter(x=df["Datetime"],y=df['Close'],name="OBTC",marker=dict(color="#636EFA"),showlegend=True))

# add line / add GBTC
fig_all.add_trace(go.Scatter(x=df["Datetime"],y=df["GBTC_Close"],name="GBTC", marker=dict(color="#FFA15A"), showlegend=True))

fig_all.update_layout(title=dict(text=' OBTC vs. GBTC ', x=0.5,),xaxis_title="Datetime",yaxis_title='Price (USD)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e6682326-7722-4457-93e7-dcb8f12a346d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6682326-7722-4457-93e7-dcb8f12a346d")) {                    Plotly.newPlot(                        "e6682326-7722-4457-93e7-dcb8f12a346d",                        [{"marker":{"color":"#636EFA"},"name":"OBTC","showlegend":true,"x":["2022-02-22 09:30","2022-02-22 10:30","2022-02-22 11:30","2022-02-22 12:30","2022-02-22 13:30","2022-02-22 14:30","2022-02-22 15:30","2022-02-23 09:30","2022-02-23 10:30","2022-02-23 11:30","2022-02-23 12:30","2022-02-23 13:30","2022-02-23 14:30","2022-02-23 15:30","2022-02-24 09:30","2022-02-24 10:30","2022-02-24 11:30","2
164,10.970000267028809,10.670000076293945,10.65999984741211,10.979999542236328,11.180000305175781,11.100000381469727,11.180000305175781,11.154999732971191,11.199999809265137,11.270000457763672,11.140000343322754,11.140000343322754,11.15999984741211,11.229999542236328,11.109999656677246,11.15999984741211,11.15999984741211,11.199999809265137,11.979999542236328,11.949999809265137,11.949999809265137,11.789999961853027,12.100000381469727,11.789999961853027,12.100000381469727,12.020000457763672,11.90999984741211,11.829999923706055,11.859999656677246,12.010000228881836,11.890000343322754,12.739999771118164,12.859999656677246,12.630000114440918,12.729999542236328,12.75,12.6899995803833,12.720000267028809,12.710000038146973,12.829999923706055,12.710000038146973,12.800000190734863,12.760000228881836,12.8100004196167,12.890000343322754,12.729999542236328,12.569999694824219,12.5,12.270000457763672,12.550000190734863,12.494999885559082,12.479999542236328,12.5,12.399999618530273,12.100000381469727,12.074999809265137,12.069999694824219,12.100000381469727,11.989999771118164,12.1899995803833,12.289999961853027,12.319999694824219,12.329999923706055,12.149999618530273,12.300000190734863,12.119999885559082,12.079999923706055,11.979999542236328,12.050000190734863,11.9399995803833,12.039999961853027,12.050000190734863,12.220000267 ...

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ดูข้อมูลแต่ละคอลัมน์

# %%
df.head()
# Out:
#            Datetime     Open    High    Low   Close  Volume  Dividends  \
# 0  2022-02-22 09:30  10.5500  10.550  10.08  10.246       0        0.0
# 1  2022-02-22 10:30  10.2400  10.270  10.13  10.196   12275        0.0
# 2  2022-02-22 11:30  10.1300  10.174  10.00  10.010    5327        0.0
# 3  2022-02-22 12:30  10.0125  10.100  10.01  10.054    5846        0.0
# 4  2022-02-22 13:30  10.1500  10.150  10.07  10.070     421        0.0
#
#    Stock Splits  Capital Gains  GBTC_Open  GBTC_Close
# 0           0.0            0.0  25.650000   26.230000
# 1           0.0            0.0  26.230000   25.910000
# 2           0.0            0.0  25.889999   25.870001
# 3           0.0            0.0  25.860001   25.799999
# 4           0.0            0.0  25.809999   26.035000

# %% [markdown]
# เพิ่มค่าเฉลี่ย10วัน, Correlation, ส่วนต่างของราคาเปิด-ปิด,เปิด-เปิด ของ [OBTC](https://finance.yahoo.com/quote/OBTC)

# %%
df['S_10'] = df['Close'].rolling(window=10).mean()
df['Corr'] = df['Close'].rolling(window=10).corr(df['S_10'])
df['Open-Close'] = df['Open'] - df['Close'].shift(1)
df['Open-Open'] = df['Open'] - df['Open'].shift(1)

# %%
df = df.dropna()
df.reset_index(drop=True,inplace=True)
df.head()
# Out:
#            Datetime   Open   High    Low  Close  Volume  Dividends  \
# 0  2022-02-24 13:30   9.75  10.04   9.75  10.04     430        0.0
# 1  2022-02-24 14:30  10.02  10.50  10.00  10.48    4311        0.0
# 2  2022-02-24 15:30  10.47  10.49  10.37  10.37    2002        0.0
# 3  2022-02-25 10:30  10.70  10.78  10.54  10.54    1180        0.0
# 4  2022-02-25 11:30  10.62  10.62  10.57  10.57     711        0.0
#
#    Stock Splits  Capital Gains  GBTC_Open  GBTC_Close     S_10      Corr  \
# 0           0.0            0.0  24.610001   25.260000  10.0564  0.519552
# 1           0.0            0.0  25.260000   26.629999  10.0600  0.039585
# 2           0.0            0.0  26.629999   26.590000  10.0720 -0.173853
# 3           0.0            0.0  27.330000   27.120001  10.1090 -0.268244
# 4           0.0            0.0  27.110001   26.960100  10.1480 -0.265131
#
#    Open-Close  Open-Open
# 0    0.000000       0.02
# 1   -0.020000       0.27
# 2   -0.009999       0.45
# 3    0.330000       0.23
# 4    0.080000      -0.08

# %% [markdown]
# กำหนดตัวแปร Target (ตัวแปร y) โดยถ้ากราฟขึ้น/ราคาปิดถัดไปมากกว่าราคาปิดก่อนหน้า จะให้ค่าเป็น"1"  และถ้ากราฟลง/ราคาปิดถัดไปน้อยกว่าหรือเท่ากับราคาปิดปัจจุบัน จะให้ค่าเป็น"-1"  เช่น ตัวแรกราคาปิดเวลา14.30 (10.48 USD) มากกว่า ราคาปิดเวลา13.30 (10.04 USD) จึงให้ค่าเป็น "1"

# %%
y = np.where(df['Close'].shift(-1) > df['Close'],1,-1)
y
# Out:
# array([ 1, -1,  1, ..., -1,  1, -1])

# %% [markdown]
# ดูว่ามีกราฟขึ้นและลง เท่าไร

# %%
print(f"- กราฟขึ้น/ ราคาปิดถัดไปมากกว่าราคาปิดก่อนหน้า         จำนวน {(y>0).sum()} ครั้ง")
print(f"- กราฟลง/ ราคาปิดถัดไปน้อยกว่าหรือเท่ากับราคาปิดก่อนหน้า จำนวน {(y<0).sum()} ครั้ง")
# Out:
# - กราฟขึ้น/ ราคาปิดถัดไปมากกว่าราคาปิดก่อนหน้า         จำนวน 1263 ครั้ง
# - กราฟลง/ ราคาปิดถัดไปน้อยกว่าหรือเท่ากับราคาปิดก่อนหน้า จำนวน 1478 ครั้ง

# %% [markdown]
# Drop Column ที่ไม่เอามา Train Model ออก

# %%
X = df.drop(['Datetime','Dividends','Stock Splits','Volume','Capital Gains'],axis=1)
X
# Out:
#        Open    High     Low  Close  GBTC_Open  GBTC_Close      S_10      Corr  \
# 0      9.75  10.040   9.750  10.04  24.610001   25.260000  10.05640  0.519552
# 1     10.02  10.500  10.000  10.48  25.260000   26.629999  10.06000  0.039585
# 2     10.47  10.490  10.370  10.37  26.629999   26.590000  10.07200 -0.173853
# 3     10.70  10.780  10.540  10.54  27.330000   27.120001  10.10900 -0.268244
# 4     10.62  10.620  10.570  10.57  27.110001   26.960100  10.14800 -0.265131
# ...     ...     ...     ...    ...        ...         ...       ...       ...
# 2736  12.80  12.820  12.080  12.18  38.480000   38.070000  12.95383  0.673683
# 2737  12.50  12.640  12.090  12.09  38.070000   38.150101  12.83783  0.855184
# 2738  12.50  12.540  12.260  12.54  38.158501   38.299999  12.80083  0.775472
# 2739  12.50  12.540  12.500  12.51  38.299999   38.535000  12.75483  0.744768
# 2740  12.69  12.695  12.645  12.68  38.540001   38.580002  12.70383  0.637817
#
#       Open-Close  Open-Open
# 0       0.000000       0.02
# 1      -0.020000       0.27
# 2      -0.009999       0.45
# 3       0.330000       0.23
# 4       0.080000      -0.08
# ...          ...        ...
# 2736   -0.023300      -0.21
# 2737    0.320000      -0.30
# 2738    0.410000       0.00
# 2739   -0.040000       0.00
# 2740    0.179999       0.19
#
# [2741 rows x 10 columns]

# %% [markdown]
# แบ่งข้อมูล Train Data : Test Data จำนวน 70 : 30

# %%
split = int(0.7*len(df))
X_train, X_test, y_train, y_test = X[:split], X[split:], y[:split], y[split:]

# %% [markdown]
# สร้างโมเดล Logistic Regression

# %%
model = LogisticRegression()
model = model.fit(X_train,y_train)

# %% [markdown]
# ตรวจสอบ Coefficients

# %%
pd.DataFrame(zip(X.columns, np.transpose(model.coef_)))
# Out:
#             0                       1
# 0        Open    [2.7374976770119943]
# 1        High   [0.26500518632580766]
# 2         Low   [0.16550242499739903]
# 3       Close   [-3.4864320245889333]
# 4   GBTC_Open   [-1.0558176551497616]
# 5  GBTC_Close    [1.1563303231034612]
# 6        S_10  [0.013655720066085208]
# 7        Corr   [0.12172967652089037]
# 8  Open-Close    [-0.694811309027037]
# 9   Open-Open   [-0.5187898096368808]

# %% [markdown]
# # วัดประสิทธิภาพของโมเดล

# %% [markdown]
# ทดสอบโมเดลกับ Test Data (X_test)

# %%
predicted = model.predict(X_test)
probability = model.predict_proba(X_test)
print(probability)
# Out:
# [[0.53451325 0.46548675]
#  [0.52862532 0.47137468]
#  [0.50936854 0.49063146]
#  ...
#  [0.50980513 0.49019487]
#  [0.36918169 0.63081831]
#  [0.48457296 0.51542704]]

# %% [markdown]
# เปรียบเทียบค่า y ที่ได้จากการ Predict Test Data (X_test) กับ y_test จริงๆ โดยใช้ Confusion Matrix

# %%
print(metrics.confusion_matrix(y_test, predicted))
# Out:
# [[301 134]
#  [177 211]]

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

ConfusionMatrixDisplay.from_predictions(y_test, predicted)
plt.show()

# %% [markdown]
# สรุปผล Logistic Regression (Classification Report)

# %%
print(metrics.classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.63      0.69      0.66       435
#            1       0.61      0.54      0.58       388
#
#     accuracy                           0.62       823
#    macro avg       0.62      0.62      0.62       823
# weighted avg       0.62      0.62      0.62       823

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
print(f"สรุปประสิทธิภาพของโมเดล Logistic Regression\n")
print(f"Accuracy  = {accuracy_score(y_test,predicted):.4f}  หรือ  {accuracy_score(y_test,predicted)*100:.2f} %")
print(f"Precision = {precision_score(y_test, predicted, average='weighted'):.4f}  หรือ  {precision_score(y_test, predicted, average='weighted')*100:.2f} %")
print(f"Recall    = {recall_score(y_test, predicted, average='weighted'):.4f}")
print(f"F1 Score  = {f1_score(y_test, predicted, average='macro'):.4f}")
# Out:
# สรุปประสิทธิภาพของโมเดล Logistic Regression
#
# Accuracy  = 0.6221  หรือ  62.21 %
# Precision = 0.6212  หรือ  62.12 %
# Recall    = 0.6221
# F1 Score  = 0.6175

# %%
df_predict = pd.DataFrame()
df_predict['y_test'] = y_test
df_predict['y_predict'] = predicted.astype('int64')
print(f"\nตารางเปรียบเทียบระหว่าง ค่าจริง(y_test) กับ ค่าที่โมเดลทำนายได้(y_predict) \n")
from IPython.display import display
with pd.option_context('display.max_rows', 100):
    display(df_predict)
# Out:
# ตารางเปรียบเทียบระหว่าง ค่าจริง(y_test) กับ ค่าที่โมเดลทำนายได้(y_predict)
#      y_test  y_predict
# 0        -1         -1
# 1        -1         -1
# 2         1         -1
# 3         1          1
# 4        -1         -1
# ..      ...        ...
# 818      -1          1
# 819       1          1
# 820      -1         -1
# 821       1          1
# 822      -1          1
#
# [823 rows x 2 columns]

# %%
df_predict2 = df_predict.replace([1, -1], ['up','down'])
print(f"\nตารางเปรียบเทียบระหว่าง ค่าจริง(y_test) กับ ค่าที่โมเดลทำนายได้(y_predict) \n")
display(df_predict2)
# Out:
# ตารางเปรียบเทียบระหว่าง ค่าจริง(y_test) กับ ค่าที่โมเดลทำนายได้(y_predict)
#     y_test y_predict
# 0     down      down
# 1     down      down
# 2       up      down
# 3       up        up
# 4     down      down
# ..     ...       ...
# 818   down        up
# 819     up        up
# 820   down      down
# 821     up        up
# 822   down        up
#
# [823 rows x 2 columns]

# %% [markdown]
# Create Trading Strategy Using The Model

# %%
Predicted_Signal = pd.DataFrame(model.predict(X))
BTC_Returns = np.log(df['Close']/df['Close'].shift(1))

#Create Dataframe
df_trade = pd.DataFrame()
df_trade['Datetime'] = df['Datetime']
df_trade['Predicted_Signal'] = Predicted_Signal
df_trade['BTC_Returns'] = BTC_Returns
Startegy_returns = df_trade['BTC_Returns']* df_trade['Predicted_Signal'].shift(1)
df_trade['Startegy_returns'] = Startegy_returns

Cumulative_BTC_returns = np.cumsum(df_trade['BTC_Returns'])
Cumulative_Strategy_returns = np.cumsum(df_trade['Startegy_returns'])

#Visualization
fig_cum = go.Figure()
fig_cum.add_trace(go.Scatter(x=df_trade["Datetime"],y=Cumulative_BTC_returns,name="BTC Returns",marker=dict(color="#636EFA"),showlegend=True))
fig_cum.add_trace(go.Scatter(x=df_trade["Datetime"],y=Cumulative_Strategy_returns,name="Strategy Returns", marker=dict(color="#EF553B"), showlegend=True))
fig_cum.update_layout(title=dict(text='BTC Returns vs. Strategy Returns', x=0.5,),xaxis_title="Datetime",yaxis_title='Cumulative Returns')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="df51eb5f-a044-4266-8921-3e5e2f006b70" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df51eb5f-a044-4266-8921-3e5e2f006b70")) {                    Plotly.newPlot(                        "df51eb5f-a044-4266-8921-3e5e2f006b70",                        [{"marker":{"color":"#636EFA"},"name":"BTC Returns","showlegend":true,"x":["2022-02-24 13:30","2022-02-24 14:30","2022-02-24 15:30","2022-02-25 10:30","2022-02-25 11:30","2022-02-25 13:30","2022-02-25 14:30","2022-02-25 15:30","2022-02-28 09:30","2022-02-28 10:30","2022-02-28 11:30","2022-02-28 12:30","2022-02-28 13:30","2022-02-28 14:30","2022-02-28 15:30","2022-03-01 09:30","2022-03-01 10:30","2022-03-01 11:30","2022-03-01 12:30","2022-03-01 13:30","2022-03-01 15:30","2022-03-02 09:30","2022-03-02 10:30","2022-03-02 11:30","2022-03-02 12:30","2022-03-02 13:30","2022-03-02 14:30","2022-03-02 15:30","2022-03-03 09:30","2022-03-03 10:30","2022-03-03 11:30","2022-03-03 12:30","2022-03-03 13:30","2022-03-03 14:30","2022-03-03 15:30","2022-03-04 09:30","2022-03-04 10:30","2022-03-04 11:30","2022-03-04 12:30","2022-03-04 13:30","2022-03-04 14:30","2022-03-04 15:30","2022-03-07 09:30","2022-03-07 10:30","2022-03-07 11:30","2022-03-07 12:30","2022-03-07 13:30","2022-03-07 14:30","2022-03-07 15:30","2022-03-08 09:30","2022-03-08 10:30","2022-03-08 11:30","2022-03-08 12:30","2022-03-08 13:30","2022-03-08 15:30","2022-03-09 09:30","2022-03-09 10:30","2022-03-09 11:30","2022-03-09 12:30","2022-03-09 13:30","2022-03-09 14:30","2022-03-09 15:30","2022-03-10 09:30","2022-03-10 12:30","2022-03-10 13:30","2022-03-10 14:30","2022-03-11 09:30","2022-03-11 11:30","2022-03-11 13:30","2022-03-11 14:30","2022-03-11 15:30","2022-03-14 09:30","2022-03-14 10:30","2022-03-14 11:30","2022-03-14 14:30","2022-03-14 15:30","2022-03-15 09:30","2022-03-15 10:30","2022-03-15 11:30","2022-03-15 12:30","2022-03-15 13:30","2022-03-15 14:30","2022-03-15 15:30","2022-03-16 09:30","2022-03-16 10:30","2022-03-16 12:30","2022-03-16 13:30","2022-03-16 14:30","2022-03-16 15:30","2022-03-17 09:30","2022-03-17 10:30","2022-03-17 11:30","2022-03-17 12:30","2022-03-17 13:30","2022-03-17 14:30","2022-03-17 15:30","2022-03-18 09:30","2022-03-18 10:30","2022-03-18 11:30","2022-03-18 12:30","2022-03-18 13:30","2022-03-18 14:30","2022-03-18 15:30","2022-03-21 09:30","2022-03-21 10:30","2022-03-21 12:30","2022-03-21 13:30","2022-03-21 14:30","2022-03-21 15:30","2022-03-22 09:30","2022-03-22 10:30","2022-03-22 11:30","2022-03-22 13:30","2022-03-22 14:30","2022-03-22 15:30","2022-03-23 09:30","2022-03-23 10:30","2022-03-23 11:30","2022-03-23 12:30","2022-03-23 13:30","2022-03-23 14:30","2022-03-23 15:30","2022-03-24 09:30","2022-03-24 10:30","2022-03-24 11:30","2022-03-24 12:30","2022-03-24 13:30","2022-03-24 14:30","2022-03-24 15:30","2022-03-25 09:30","2022-03-25 10:30","2022-03-25 11:30","2022-03-25 12:30","2022-03-25 13:30","2022-03-25 14:30","2022-03-25 15:30","2022-03-28 09:30","2022-03-28 10:30","2022-03-28 11:30","2022-03-28 12:30","2022-03-28 13:30","2022-03-28 14:30","2022-03-28 15:30","2022-03-29 09:30","2022-03-29 10:30","2022-03-29 11:30","2022-03-29 12:30","2022-03-29 13:30","2022-03-29 14:30","2022-03-29 15:30","2022-03-30 09:30","2022-03-30 10:30","2022-03-30 11:30","2022-03-30 12:30","2022-03-30 13:30","2022-03-30 14:30","2022-03-30 15:30","2022-03-31 09:30","2022-03-31 11:30","2022-03-31 12:30","2022-03-31 13:30","2022-03-31 14:30","2022-03-31 15:30","2022-04-01 09:30","2022-04-01 10:30","2022-04-01 11:30","2022-04-01 12:30","2022-04-01 13:30","2022-04-01 14:30","2022-04-01 15:30","2022-04-04 09:30","2022-04-04 10:30","2022-04-04 11:30","2022-04-04 12:30","2022-04-04 13:30","2022-04-04 14:30","2022-04-04 15:30" ...

# %%
#Plot Trading Strategy โดยใช้ Matplotlib

df_trades = pd.DataFrame()
df_trades['Cum_BTC'] = Cumulative_BTC_returns
df_trades['Cum_Stg'] = Cumulative_Strategy_returns
df_trades['Datetime'] = df_trade['Datetime']
df_trades.set_index(['Datetime'],inplace=True)

plt.figure(figsize=(16, 8))
df_trades['Cum_BTC'].plot(label='BTC Returns')
df_trades['Cum_Stg'].plot(label='Strategy Returns')
plt.title('BTC Returns vs. Strategy Returns')
plt.xlabel('Datetime')
plt.ylabel('Price (USD)')
plt.legend()
